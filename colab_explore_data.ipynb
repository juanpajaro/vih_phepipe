# %%
import explore_data
import pandas as pd
import utils_general_porpose
import os

# %%
current_dir = os.getcwd()
print("Current directory:", current_dir)
data = utils_general_porpose.load_json(current_dir, "/concepts/clinical_concepts_20250404_171428.json")
df = pd.DataFrame(data)
df['label'] = df['label'].astype('int')
df.info()
# Out:
# Current directory: /home/pajaro/compu_Pipe_V3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  924 non-null    int64
#  1   label       924 non-null    int64
#  2   entities    924 non-null    object
#  3   codes       924 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 29.0+ KB

# %%
num_classes = explore_data.get_num_classes(df['label'])
print("Number of classes:", num_classes)
# Out:
# Number of classes: 2

# %%
print("Median number of words per sample:", explore_data.get_num_words_per_sample(df['entities']))
# Out:
# Median number of words per sample: 23.0

# %%
ngrams, counts = explore_data.plot_frequency_distribution_of_ngrams_v2(df['entities'], ngram_range=(1, 2), num_ngrams=10)

# %%
print(type(ngrams))
print(len(ngrams))
print("N-grams:", ngrams[:10])
print(ngrams[-50:])
print(type(counts))
print(len(counts))
print("Counts:", counts[:10])
# Out:
# <class 'tuple'>
# 26745
# N-grams: ('enfermedad', 'obesidad', 'hipotiroidismo', 'dislipidemia', 'leucocitos', 'asma', 'asma_no_especificada', 'hipertension_arterial', 'anemia', 'enfermedad_renal')
# ...

# %%
explore_data.plot_sample_length_distribution(df['entities'])

# %%
explore_data.plot_class_distribution(df['label'])
